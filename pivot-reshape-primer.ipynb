# %%
import numpy as np
import pandas as pd

# %%
dates = pd.date_range('20130101', periods=6)

print(dates)

df = pd.DataFrame(data= {'date': dates.repeat(3),
                         'variable': 'A B C'.split() * 6,
                         'value': np.random.randn(18)})
df
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')
#          date     value variable
# 0  2013-01-01 -0.017024        A
# 1  2013-01-01 -1.439303        B
# 2  2013-01-01  0.087758        C
# 3  2013-01-02  0.070238        A
# 4  2013-01-02 -0.300528        B
# 5  2013-01-02  0.456655        C
# 6  2013-01-03  0.302955        A
# 7  2013-01-03 -0.999599        B
# 8  2013-01-03 -0.224275        C
# 9  2013-01-04 -0.962348        A
# 10 2013-01-04 -0.667280        B
# 11 2013-01-04  0.645405        C
# 12 2013-01-05 -0.176415        A
# 13 2013-01-05 -0.096062        B
# 14 2013-01-05  1.855340        C
# 15 2013-01-06 -1.231219        A
# 16 2013-01-06  0.526050        B
# 17 2013-01-06 -0.966285        C

# %%
df.pivot(index='date', columns='variable', values='value')
# Out:
# variable           A         B         C
# date
# 2013-01-01 -0.017024 -1.439303  0.087758
# 2013-01-02  0.070238 -0.300528  0.456655
# 2013-01-03  0.302955 -0.999599 -0.224275
# 2013-01-04 -0.962348 -0.667280  0.645405
# 2013-01-05 -0.176415 -0.096062  1.855340
# 2013-01-06 -1.231219  0.526050 -0.966285

# %%
df2 = pd.DataFrame({ 'A' : 1.,
                    'B' : pd.Timestamp('20130102'),
                    'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                    'D' : np.array([3] * 4,dtype='int32'),
                    'E' : pd.Categorical(["test","train","test","train"]),
                    'F' : 'foo' })
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
p = df2.pivot_table(index='B', columns=['E','F'], values=['C', 'D'], aggfunc=np.sum)
p
# Out:
#               C          D
# E          test train test train
# F           foo   foo  foo   foo
# B
# 2013-01-02  2.0   2.0    6     6
